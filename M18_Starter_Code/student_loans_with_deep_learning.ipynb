# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: credit_ranking, Length: 1599, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns="credit_ranking")

# Review the features DataFrame
X
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0                 7.4               0.700               0.00          1.9
# 1                 7.8               0.880               0.00          2.6
# 2                 7.8               0.760               0.04          2.3
# 3                11.2               0.280               0.56          1.9
# 4                 7.4               0.700               0.00          1.9
# ...               ...                 ...                ...          ...
# 1594              6.2               0.600               0.08          2.0
# 1595              5.9               0.550               0.10          2.2
# 1596              6.3               0.510               0.13          2.3
# 1597              5.9               0.645               0.12          2.0
# 1598              6.0               0.310               0.47          3.6
#
#       alumni_success  study_major_code  time_to_completion  \
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
scaler.fit(X_train)

# Fit the scaler to the features training dataset
# Out:
# StandardScaler()

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
num_inputs = X_train.shape[1]

# Review the number of features
num_inputs
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer
num_output_neurons = 1

# %%
# Create the Sequential model instance
model = Sequential()

# Add the first hidden layer
model.add(Dense(6, input_dim=num_inputs, activation='relu'))

# Add the second hidden layer
model.add(Dense(3, activation='relu'))

# Add the output layer to the model specifying the number of output neurons and activation function
model.add(Dense(1, activation='sigmoid'))

# %%
# Display the Sequential model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 6)                 72
#
#  dense_4 (Dense)             (None, 3)                 21
#
#  dense_5 (Dense)             (None, 1)                 4
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit the model using 50 epochs and the training data
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 40/40 [==============================] - 2s 12ms/step - loss: 0.7495 - accuracy: 0.5012 - val_loss: 0.6895 - val_accuracy: 0.4938
# Epoch 2/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6905 - accuracy: 0.4957 - val_loss: 0.6871 - val_accuracy: 0.4969
# Epoch 3/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.4949 - val_loss: 0.6869 - val_accuracy: 0.5312
# Epoch 4/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6835 - accuracy: 0.5152 - val_loss: 0.6847 - val_accuracy: 0.5594
# Epoch 5/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.6830 - accuracy: 0.5278 - val_loss: 0.6812 - val_accuracy: 0.5344
# Epoch 6/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6813 - accuracy: 0.5145 - val_loss: 0.6836 - val_accuracy: 0.6344
# Epoch 7/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Display the model loss and accuracy results
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6519 - accuracy: 0.6250
# Loss: 0.651888370513916, Accuracy: 0.625

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Export your model to a keras file
model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_imported.predict(X_test)

# Display a sample of the predictions
print(predictions[:5])
# Out:
# 10/10 [==============================] - 0s 2ms/step
# [[0.5091185 ]
#  [0.4072944 ]
#  [0.6324416 ]
#  [0.56247747]
#  [0.64338106]]

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
rounded_predictions = predictions.round().astype(int)
predictions_df = pd.DataFrame(rounded_predictions, columns=['Predicted'])
predictions_df.head()
# Out:
#    Predicted
# 0          1
# 1          0
# 2          1
# 3          1
# 4          1

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, rounded_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.44      0.53       154
#            1       0.60      0.80      0.69       166
#
#     accuracy                           0.62       320
#    macro avg       0.64      0.62      0.61       320
# weighted avg       0.64      0.62      0.61       320

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
# Demographic info, Finanial info, educational background, laon preferences, user behavior and feedback, market trends and loan offerings. By collecting and analyzing this data, a recommendation system can provide personalized loan options tailored to each student's financial situation, educational needs, and preferences. This approach can help students make informed decisions about their financing options, potentially reducing financial stress and improving their overall academic experience.
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
# Based on the data selected for building the recommendation system for student loan options, the model would likely use a combination of content-based filtering and context-based filtering. By leveraging both content-based and context-based filtering approaches, the recommendation system can provide personalized and relevant loan options tailored to each student's unique profile and current situation. This hybrid approach allows the system to consider both the intrinsic characteristics of the loan options and the external contextual factors that may influence the student's decision-making process.
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
#
#
# Building a recommendation system for student loans comes with several real-world challenges that need to be carefully considered. Two significant challenges and why they are of concern for a student loan recommendation system would be data privacy and security, and bias and fairness. Addressing these challenges requires a holistic approach that combines technical solutions, ethical considerations, and regulatory compliance measures. Implementing robust data privacy safeguards, anonymization techniques, encryption protocols, and access controls can mitigate the risks associated with data privacy and security. Additionally, employing fairness-aware algorithms, bias detection tools, and regular audits can help mitigate biases and ensure equitable outcomes in loan recommendations. Ultimately, prioritizing transparency, accountability, and stakeholder engagement is essential for building trust and credibility in student loan recommendation systems while safeguarding the interests and well-being of students.
